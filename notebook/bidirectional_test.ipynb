# %%
import time
from datetime import datetime
import numpy as np
import tensorflow as tf
from model.vae import cnn_vae_rnn
from util.miditools import piano_roll_to_pretty_midi
# Out:
# /home/eko/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
##################################################################
# Setting up constants and loading the data
##################################################################

# nintendo
nintendo_file = './Downloads/node-vgmusic-downloader/download/console/nintendo/gameboy/'
# nottingham
nottingham_file = './Downloads/node-vgmusic-downloader/download/console/microsoft/xbox/'

# 'wget '+'http://www-etud.iro.umontreal.ca/~boulanni/JSB%20Chorales.pickle -O '
# 'wget '+'http://www-etud.iro.umontreal.ca/~boulanni/Nottingham.pickle -O '
# 'wget '+'http://www-etud.iro.umontreal.ca/~boulanni/MuseData.pickle -O '
# 'wget '+'http://www-etud.iro.umontreal.ca/~boulanni/Piano-midi.de.pickle -O '
# Out:
# /home/eko/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
snapshot_interval = 200
log_interval = 50

checkpoint_file = './tfmodel/exp-omnibook-bigru-iter-%s-trainloss-%s-c-major.tfmodel'
# mudb_file = '../Nottingham/preprocessing/CN_mudb_train.npz'
# dev_file = '../Nottingham/preprocessing/CN_mudb_valid.npz'
dev_file = '/home/eko/Downloads/Omnibook/Midi/preprocessing/mudb_train.npz'

# train_data = np.load(mudb_file)
dev_data = np.load(dev_file)
# print range(train_data['bars'])

# %%
# fs = train_data['fs']
fs = dev_data['fs']
print fs

num_timesteps = int(fs)
# bars = train_data['bars']
devBars = dev_data['bars']
# np.random.shuffle(bars)

print devBars.shape
# print len(bars)
# Out:
# 100
# (0,)

# %%
note_range = int(devBars.shape[2])


T = int(train_data['T']) #16
num_batches = int(bars.shape[0])

height = num_timesteps #19
width = note_range #128
n_visible = note_range * num_timesteps
n_epochs = 100

z_dim = 350
X_dim = width * height
n_hidden = z_dim
h_dim = z_dim
batch_size = 32

trainBarsBatch = np.reshape(devBars, (-1, T, height, width, 1))
trainBarsBatches = []
i = 0
while i < trainBarsBatch.shape[0] - 32:
    trainBarsBatches.append(trainBarsBatch[i:i+32])
    i += 32
devBarsBatch = np.reshape(devBars, (-1, T, height, width, 1))
devBarsBatches = []
i = 0
while i < devBarsBatch.shape[0] - 32:
    devBarsBatches.append(devBarsBatch[i:i+32])
    i += 32
#devBarsBatch = np.array_split(devBarsBatch, batch_size)
initializer = tf.contrib.layers.xavier_initializer()

audio_sr = 44100

devLoss = True
devInterval = 100
# Out:
# ---------------------------------------------------------
# IndexError              Traceback (most recent call last)
# <ipython-input-8-993ad2a6a5a2> in <module>()
# ----> 1 note_range = int(devBars.shape[2])
#       2
#       3
#       4 T = int(train_data['T']) #16
#       5 num_batches = int(bars.shape[0])
#
# IndexError: tuple index out of range

# %%
##################################################################
# Loading the model
##################################################################
with tf.name_scope('placeholders'):
    z = tf.placeholder(tf.float32, shape=[None, z_dim], name="Generated_noise")
    #(batch x T x width x height x channels)
    z_rnn_samples = tf.placeholder(tf.float32, shape=[None, T, height, width, 1], name="Generated_midi_input")
    
    X = tf.placeholder(tf.float32, shape=[None, T, height, width, 1], name="Training_samples")
    kl_annealing = tf.placeholder(tf.float32, name="KL_annealing_multiplier")

    
# model selection
model = cnn_vae_rnn(X, z, z_rnn_samples, X_dim, z_dim=z_dim, h_dim=h_dim, initializer=initializer, keep_prob=1.0)
# model = cnn_vae_rnn(X, z, z_rnn_samples, X_dim, z_dim=z_dim, h_dim=h_dim, initializer=initializer, keep_prob=1.0)
# model = cnn_vae
# model = cnn_rnn
# model = vae_rnn
# model = vae
# model = rnn


X_samples, out_samples, logits = (model['X_samples'], model['out_samples'], model['logits'])
z_mu, z_logvar = (model['z_mu'], model['z_logvar'])

# %%
##################################################################
# Losses
##################################################################
with tf.name_scope("Loss"):
    X_labels = tf.reshape(X, [-1, width*height])

    with tf.name_scope("cross_entropy"):
        recon_loss = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=X_labels), 1)
    with tf.name_scope("kl_divergence"):
        kl_loss = kl_annealing * 0.5 * tf.reduce_sum(tf.square(z_mu) + tf.exp(z_logvar) - z_logvar - 1.,1) 
    
    recon_loss = tf.reduce_mean(tf.reshape(recon_loss, [-1, T]), axis=1)

    loss = tf.reduce_mean(recon_loss + kl_loss)

# %%
##################################################################
# Optimizer
##################################################################
with tf.name_scope("Optimizer"):
    solver = tf.train.AdamOptimizer()
    grads = solver.compute_gradients(loss)
    grads = [(tf.clip_by_norm(g, clip_norm=1), v) for g, v in grads]
    train_op = solver.apply_gradients(grads)

##################################################################
# Logging
##################################################################
with tf.name_scope("Logging"):
    recon_loss_ph = tf.placeholder(tf.float32)
    kl_loss_ph = tf.placeholder(tf.float32)
    loss_ph = tf.placeholder(tf.float32)
    audio_ph = tf.placeholder(tf.float32)

    tf.summary.scalar("Reconstruction_loss", recon_loss_ph)
    tf.summary.scalar("KL_loss", kl_loss_ph)
    tf.summary.scalar("Loss", loss_ph)
    tf.summary.audio("sample_output", audio_ph, audio_sr)
    log_op = tf.summary.merge_all()

writer = tf.summary.FileWriter('./tb/', graph=tf.get_default_graph())

sess = tf.Session(config=tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True)))
#sess = tf.Session(config=tf.ConfigProto(device_count={'GPU': 0}))

# Run Initialization operations
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver()

loss_avg = 0.0
decay = 0.99
min_loss = 100.0
min_dev_loss = 200.0
time0 = time.time()
##################################################################
# Optimization loop
##################################################################
i = 0
for e in range(n_epochs):
    print("%s EPOCH %d %s" % ("".join(10*["="]), e, "".join(10*["="])))
    for batch in trainBarsBatches:
        kl_an = 1.0#min(1.0, (i / 10) / 200.)
        _,loss_out, kl, recon = sess.run([train_op, loss, kl_loss, recon_loss], feed_dict={X: batch, kl_annealing: kl_an})

        if (i % log_interval) == 0:
            loss_avg = decay*loss_avg + (1-decay)*loss_out
            print('\titer = %d, local_loss (cur) = %f, local_loss (avg) = %f, kl = %f'
                % (i, loss_out, loss_avg, np.mean(kl)))
            
            time_spent = time.time() - time0
            print('\n\tTotal time elapsed: %f sec. Average time per batch: %f sec\n' %
                (time_spent, time_spent / (i+1)))
            #Random samples
            z_in = np.random.randn(1, z_dim)
            z_rnn_out = np.zeros((T,height,width,1))
            first = True
            for j in range(T):
                z_rnn_out = np.expand_dims(z_rnn_out, axis=0)
                samples = sess.run(X_samples, feed_dict={z: np.random.randn(1, z_dim), X: z_rnn_out})
                frames = j + 1
                samples = samples.reshape((-1, height, width, 1))
                z_rnn_out = np.concatenate([samples[:frames], np.zeros((T-frames, height, width, 1))])
            samples = samples.reshape((num_timesteps*(T), note_range))
            thresh_S = samples >= 0.5
            
            pm_out = piano_roll_to_pretty_midi(thresh_S.T * 127, fs=fs)
            midi_out = './tb/audio/test002_{0}.mid'.format(datetime.now().strftime("%Y.%m.%d.%H:%M:%S"))
            wav_out = './tb/audio/test002_{0}.wav'.format(datetime.now().strftime("%Y.%m.%d.%H:%M:%S"))
            audio = pm_out.synthesize() 
            audio = audio.reshape((1, len(audio)))
            #Write out logs
            summary = sess.run(log_op, feed_dict={recon_loss_ph: np.mean(recon), kl_loss_ph: np.mean(kl),
                                                 loss_ph: loss_out, audio_ph: audio})
            writer.add_summary(summary, i)
        
        if devLoss and i % devInterval == 0:
            #dls = []
            #for dbatch in devBarsBatches:
            #    dev_loss_out, kl, recon = sess.run([loss, kl_loss, recon_loss], feed_dict={X: dbatch, kl_annealing: kl_an})
            #    dls.append(dev_loss_out)
            #dev_loss_out = sum(dls) / len(dls)
            #print("Dev set loss %.2f" % dev_loss_out)

            if loss_out < min_dev_loss:
                print("Saving checkpoint with train loss %d" % loss_out)
                min_dev_loss = loss_out
                saver.save(sess, checkpoint_file % (i, str(int(loss_out))))
        i += 1
# Out:
# ========== EPOCH 0 ==========
# 	iter = 0, local_loss (cur) = 1709.529419, local_loss (avg) = 17.095294, kl = 233.321899
#
# 	Total time elapsed: 4.123551 sec. Average time per batch: 4.123551 sec
#
# 	iter = 50, local_loss (cur) = 238.183105, local_loss (avg) = 19.306172, kl = 5.837939
#
# 	Total time elapsed: 156.880856 sec. Average time per batch: 3.076095 sec
#
# 	iter = 100, local_loss (cur) = 169.861908, local_loss (avg) = 20.811730, kl = 2.354903
#
# 	Total time elapsed: 302.692744 sec. Average time per batch: 2.996958 sec
#
# Saving checkpoint with train loss 169
# 	iter = 150, local_loss (cur) = 161.750061, local_loss (avg) = 22.221113, kl = 0.021598
#
# 	Total time elapsed: 442.439389 sec. Average time per batch: 2.930062 sec
#
# 	iter = 200, local_loss (cur) = 159.876190, local_loss (avg) = 23.597664, kl = 0.066941
#
# 	Total time elapsed: 578.155188 sec. Average time per batch: 2.876394 sec
#
# Saving checkpoint with train loss 159
# 	iter = 250, local_loss (cur) = 105.702789, local_loss (avg) = 24.418715, kl = 0.008332
#
# 	Total time elapsed: 714.172673 sec. Average time per batch: 2.845309 sec
#
# ========== EPOCH 1 ==========
# 	iter = 300, local_loss (cur) = 154.720215, local_loss (avg) = 25.721730, kl = 0.128790
#
# 	Total time elapsed: 849.662941 sec. Average time per batch: 2.822800 sec
#
# Saving checkpoint with train loss 154
# 	iter = 350, local_loss (cur) = 156.449219, local_loss (avg) = 27.029005, kl = 0.005960
#
# 	Total time elapsed: 986.299200 sec. Average time per batch: 2.809969 sec
#
# 	iter = 400, local_loss (cur) = 159.519257, local_loss (avg) = 28.353907, kl = 0.003483
#
# 	Total time elapsed: 1122.545675 sec. Average time per batch: 2.799366 sec
#
# 	iter = 450, local_loss (cur) = 197.191589, local_loss (avg) = 30.042284, kl = 1.853132
#
# 	Total time elapsed: 1258.272892 sec. Average time per batch: 2.789962 sec
#
# 	iter = 500, local_loss (cur) = 174.205353, local_loss (avg) = 31.483915, kl = 0.002938
#
# 	Total time elapsed: 1394.238964 sec. Average time per batch: 2.782912 sec
#
# 	iter = 550, local_loss (cur) = 168.869751, local_loss (avg) = 32.857773, kl = 0.004602
#
# 	Total time elapsed: 1529.502891 sec. Average time per batch: 2.775867 sec
#
# ========== EPOCH 2 ==========
# 	iter = 600, local_loss (cur) = 133.475922, local_loss (avg) = 33.863955, kl = 0.008027
#
# 	Total time elapsed: 1665.244409 sec. Average time per batch: 2.770789 sec
#
# Saving checkpoint with train loss 133
# 	iter = 650, local_loss (cur) = 147.136383, local_loss (avg) = 34.996679, kl = 0.002824
#
# 	Total time elapsed: 1801.593362 sec. Average time per batch: 2.767425 sec
#
# 	iter = 700, local_loss (cur) = 154.389679, local_loss (avg) = 36.190609, kl = 0.120001
#
# 	Total time elapsed: 1937.420530 sec. Average time per batch: 2.763795 sec
#
# 	iter = 750, local_loss (cur) = 152.482941, local_loss (avg) = 37.353532, kl = 0.002543
#
# 	Total time elapsed: 2072.738306 sec. Average time per batch: 2.759971 sec
#
# 	iter = 800, local_loss (cur) = 168.498596, local_loss (avg) = 38.664983, kl = 0.002724
#
# 	Total time elapsed: 2208.480053 sec. Average time per batch: 2.757154 sec
#
# ========== EPOCH 3 ==========
# 	iter = 850, local_loss (cur) = 142.556305, local_loss (avg) = 39.703896, kl = 0.003497
#
# 	Total time elapsed: 2344.034201 sec. Average time per batch: 2.754447 sec
#
# 	iter = 900, local_loss (cur) = 167.203247, local_loss (avg) = 40.978890, kl = 0.006732
#
# 	Total time elapsed: 2479.977956 sec. Average time per batch: 2.752473 sec
#
# 	iter = 950, local_loss (cur) = 138.079941, local_loss (avg) = 41.949900, kl = 0.004732
#
# 	Total time elapsed: 2616.100944 sec. Average time per batch: 2.750895 sec
#
# 	iter = 1000, local_loss (cur) = 170.854874, local_loss (avg) = 43.238950, kl = 0.028477
#
# 	Total time elapsed: 2753.101875 sec. Average time per batch: 2.750352 sec
#
# 	iter = 1050, local_loss (cur) = 137.891418, local_loss (avg) = 44.185475, kl = 0.004116
#
# 	Total time elapsed: 2888.974114 sec. Average time per batch: 2.748786 sec
#
# 	iter = 1100, local_loss (cur) = 131.898361, local_loss (avg) = 45.062604, kl = 0.002434
#
# 	Total time elapsed: 3024.725825 sec. Average time per batch: 2.747253 sec
#
# Saving checkpoint with train loss 131
# ========== EPOCH 4 ==========
# 	iter = 1150, local_loss (cur) = 180.577118, local_loss (avg) = 46.417749, kl = 0.349063
#
# 	Total time elapsed: 3161.037503 sec. Average time per batch: 2.746340 sec
#
# 	iter = 1200, local_loss (cur) = 178.971024, local_loss (avg) = 47.743281, kl = 0.006098
#
# 	Total time elapsed: 3296.843990 sec. Average time per batch: 2.745082 sec
#
# 	iter = 1250, local_loss (cur) = 154.251984, local_loss (avg) = 48.808368, kl = 0.002115
#
# 	Total time elapsed: 3432.944314 sec. Average time per batch: 2.744160 sec
#
# 	iter = 1300, local_loss (cur) = 149.132629, local_loss (avg) = 49.811611, kl = 0.007225
#
# 	Total time elapsed: 3569.353782 sec. Average time per batch: 2.743546 sec
#
# 	iter = 1350, local_loss (cur) = 127.723389, local_loss (avg) = 50.590729, kl = 0.003268
#
# 	Total time elapsed: 3704.655518 sec. Average time per batch: 2.742158 sec
#
# ========== EPOCH 5 ==========
# 	iter = 1400, local_loss (cur) = 149.992157, local_loss (avg) = 51.584743, kl = 0.001389
#
# 	Total time elapsed: 3840.399895 sec. Average time per batch: 2.741185 sec
#
# 	iter = 1450, local_loss (cur) = 186.919830, local_loss (avg) = 52.938094, kl = 0.003481
#
# 	Total time elapsed: 3976.951965 sec. Average time per batch: 2.740835 sec
#
# 	iter = 1500, local_loss (cur) = 141.325653, local_loss (avg) = 53.821970, kl = 0.001567
#
# 	Total time elapsed: 4113.510192 sec. Average time per batch: 2.740513 sec
#
# 	iter = 1550, local_loss (cur) = 126.744743, local_loss (avg) = 54.551197, kl = 0.003773
#
# 	Total time elapsed: 4248.826964 sec. Average time per batch: 2.739411 sec
#
# 	iter = 1600, local_loss (cur) = 134.035065, local_loss (avg) = 55.346036, kl = 0.009990
#
# 	Total time elapsed: 4384.226039 sec. Average time per batch: 2.738430 sec
#
# 	iter = 1650, local_loss (cur) = 131.999115, local_loss (avg) = 56.112567, kl = 0.002479
#
# 	Total time elapsed: 4520.483773 sec. Average time per batch: 2.738028 sec
#
# ========== EPOCH 6 ==========
# 	iter = 1700, local_loss (cur) = 194.581223, local_loss (avg) = 57.497253, kl = 0.004874
#
# 	Total time elapsed: 4656.539883 sec. Average time per batch: 2.737531 sec
#
# 	iter = 1750, local_loss (cur) = 156.726318, local_loss (avg) = 58.489544, kl = 0.012216
#
# 	Total time elapsed: 4792.388490 sec. Average time per batch: 2.736944 sec
#
# 	iter = 1800, local_loss (cur) = 139.217072, local_loss (avg) = 59.296819, kl = 0.005245
#
# 	Total time elapsed: 4928.538745 sec. Average time per batch: 2.736557 sec
#
# 	iter = 1850, local_loss (cur) = 135.332993, local_loss (avg) = 60.057181, kl = 0.014968
#
# 	Total time elapsed: 5063.995858 sec. Average time per batch: 2.735816 sec
#
# 	iter = 1900, local_loss (cur) = 150.946030, local_loss (avg) = 60.966069, kl = 0.000879
#
# 	Total time elapsed: 5199.890843 sec. Average time per batch: 2.735345 sec
#
# ========== EPOCH 7 ==========
# 	iter = 1950, local_loss (cur) = 147.758667, local_loss (avg) = 61.833995, kl = 0.002982
#
# 	Total time elapsed: 5335.467681 sec. Average time per batch: 2.734735 sec
#
# 	iter = 2000, local_loss (cur) = 145.289978, local_loss (avg) = 62.668555, kl = 0.005094
#
# 	Total time elapsed: 5471.043035 sec. Average time per batch: 2.734154 sec
#
# 	iter = 2050, local_loss (cur) = 166.742538, local_loss (avg) = 63.709295, kl = 0.003151
#
# 	Total time elapsed: 5607.128202 sec. Average time per batch: 2.733851 sec
#
# 	iter = 2100, local_loss (cur) = 165.067551, local_loss (avg) = 64.722878, kl = 0.003436
#
# 	Total time elapsed: 5743.269432 sec. Average time per batch: 2.733588 sec
#
# 	iter = 2150, local_loss (cur) = 163.112549, local_loss (avg) = 65.706774, kl = 0.007192
#
# 	Total time elapsed: 5880.000321 sec. Average time per batch: 2.733612 sec
#
# 	iter = 2200, local_loss (cur) = 135.348969, local_loss (avg) = 66.403196, kl = 0.003152
#
# 	Total time elapsed: 6015.523305 sec. Average time per batch: 2.733086 sec
#
# ========== EPOCH 8 ==========
# 	iter = 2250, local_loss (cur) = 109.177727, local_loss (avg) = 66.830942, kl = 0.003879
#
# 	Total time elapsed: 6151.767170 sec. Average time per batch: 2.732904 sec
#
# 	iter = 2300, local_loss (cur) = 133.029266, local_loss (avg) = 67.492925, kl = 0.012740
#
# 	Total time elapsed: 6288.281507 sec. Average time per batch: 2.732847 sec
#
# 	iter = 2350, local_loss (cur) = 172.096863, local_loss (avg) = 68.538964, kl = 0.004087
#
# 	Total time elapsed: 6424.146242 sec. Average time per batch: 2.732516 sec
#
# 	iter = 2400, local_loss (cur) = 141.774277, local_loss (avg) = 69.271317, kl = 0.009378
#
# 	Total time elapsed: 6559.679543 sec. Average time per batch: 2.732061 sec
#
# 	iter = 2450, local_loss (cur) = 162.182236, local_loss (avg) = 70.200427, kl = 0.002417
#
# 	Total time elapsed: 6695.556207 sec. Average time per batch: 2.731765 sec
#
# 	iter = 2500, local_loss (cur) = 146.196869, local_loss (avg) = 70.960391, kl = 0.010904
#
# 	Total time elapsed: 6831.673318 sec. Average time per batch: 2.731577 sec
#
# ========== EPOCH 9 ==========
# 	iter = 2550, local_loss (cur) = 164.265228, local_loss (avg) = 71.893439, kl = 0.878925
#
# 	Total time elapsed: 6967.506088 sec. Average time per batch: 2.731284 sec
#
# 	iter = 2600, local_loss (cur) = 135.040848, local_loss (avg) = 72.524913, kl = 0.007207
#
# 	Total time elapsed: 7103.318112 sec. Average time per batch: 2.730995 sec
#
# 	iter = 2650, local_loss (cur) = 162.415283, local_loss (avg) = 73.423817, kl = 0.007512
#
# 	Total time elapsed: 7239.069079 sec. Average time per batch: 2.730694 sec
#
# 	iter = 2700, local_loss (cur) = 156.707611, local_loss (avg) = 74.256655, kl = 0.005171
#
# 	Total time elapsed: 7374.427884 sec. Average time per batch: 2.730258 sec
#
# 	iter = 2750, local_loss (cur) = 107.402863, local_loss (avg) = 74.588117, kl = 0.011560
#
# 	Total time elapsed: 7510.454219 sec. Average time per batch: 2.730082 sec
#
# ========== EPOCH 10 ==========
# 	iter = 2800, local_loss (cur) = 142.185699, local_loss (avg) = 75.264093, kl = 0.005639
#
# 	Total time elapsed: 7646.118757 sec. Average time per batch: 2.729782 sec
#
# 	iter = 2850, local_loss (cur) = 208.086807, local_loss (avg) = 76.592320, kl = 0.010179
#
# 	Total time elapsed: 7782.728930 sec. Average time per batch: 2.729824 sec
#
# 	iter = 2900, local_loss (cur) = 150.220474, local_loss (avg) = 77.328602, kl = 0.001885
#
# 	Total time elapsed: 7918.793317 sec. Average time per batch: 2.729677 sec
#
# 	iter = 2950, local_loss (cur) = 151.741577, local_loss (avg) = 78.072731, kl = 0.010460
#
# 	Total time elapsed: 8054.142686 sec. Average time per batch: 2.729293 sec
#
# 	iter = 3000, local_loss (cur) = 148.792908, local_loss (avg) = 78.779933, kl = 0.003415
#
# 	Total time elapsed: 8189.814590 sec. Average time per batch: 2.729029 sec
#
# 	iter = 3050, local_loss (cur) = 95.375969, local_loss (avg) = 78.945894, kl = 0.000995
#
# 	Total time elapsed: 8325.575374 sec. Average time per batch: 2.728802 sec
#
# ========== EPOCH 11 ==========
# 	iter = 3100, local_loss (cur) = 76.850021, local_loss (avg) = 78.924935, kl = 0.000727
#
# 	Total time elapsed: 8462.070222 sec. Average time per batch: 2.728820 sec
#
# Saving checkpoint with train loss 76
# 	iter = 3150, local_loss (cur) = 96.122475, local_loss (avg) = 79.096910, kl = 0.001359
#
# 	Total time elapsed: 8598.662648 sec. Average time per batch: 2.728868 sec
#
# 	iter = 3200, local_loss (cur) = 108.922424, local_loss (avg) = 79.395165, kl = 0.000700
#
# 	Total time elapsed: 8734.552883 sec. Average time per batch: 2.728695 sec
#
# 	iter = 3250, local_loss (cur) = 129.154602, local_loss (avg) = 79.892760, kl = 0.007895
#
# 	Total time elapsed: 8870.735758 sec. Average time per batch: 2.728618 sec
#
# 	iter = 3300, local_loss (cur) = 97.610046, local_loss (avg) = 80.069933, kl = 0.000783
#
# 	Total time elapsed: 9006.936874 sec. Average time per batch: 2.728548 sec
#
# ========== EPOCH 12 ==========
# 	iter = 3350, local_loss (cur) = 79.343109, local_loss (avg) = 80.062664, kl = 0.001421
#
# 	Total time elapsed: 9143.100110 sec. Average time per batch: 2.728469 sec
#
# 	iter = 3400, local_loss (cur) = 94.234505, local_loss (avg) = 80.204383, kl = 0.020735
#
# 	Total time elapsed: 9279.692003 sec. Average time per batch: 2.728519 sec
#
# 	iter = 3450, local_loss (cur) = 74.677879, local_loss (avg) = 80.149118, kl = 0.001351
#
# 	Total time elapsed: 9416.344506 sec. Average time per batch: 2.728584 sec
#
# 	iter = 3500, local_loss (cur) = 89.702713, local_loss (avg) = 80.244654, kl = 0.006325
#
# 	Total time elapsed: 9552.532833 sec. Average time per batch: 2.728516 sec
#
# 	iter = 3550, local_loss (cur) = 77.955788, local_loss (avg) = 80.221765, kl = 0.001059
#
# 	Total time elapsed: 9687.787255 sec. Average time per batch: 2.728186 sec
#
# 	iter = 3600, local_loss (cur) = 117.597687, local_loss (avg) = 80.595524, kl = 0.000767
#
# 	Total time elapsed: 9825.328522 sec. Average time per batch: 2.728500 sec
#
# ========== EPOCH 13 ==========
# 	iter = 3650, local_loss (cur) = 86.148529, local_loss (avg) = 80.651054, kl = 0.001134
#
# 	Total time elapsed: 9961.380900 sec. Average time per batch: 2.728398 sec
#
# 	iter = 3700, local_loss (cur) = 69.229523, local_loss (avg) = 80.536839, kl = 0.001205
#
# 	Total time elapsed: 10097.875318 sec. Average time per batch: 2.728418 sec
#
# Saving checkpoint with train loss 69
# 	iter = 3750, local_loss (cur) = 102.939377, local_loss (avg) = 80.760864, kl = 0.002041
#
# 	Total time elapsed: 10234.868410 sec. Average time per batch: 2.728571 sec
#
# 	iter = 3800, local_loss (cur) = 69.460480, local_loss (avg) = 80.647860, kl = 0.007774
#
# 	Total time elapsed: 10370.910361 sec. Average time per batch: 2.728469 sec
#
# 	iter = 3850, local_loss (cur) = 64.496605, local_loss (avg) = 80.486348, kl = 0.000411
#
# 	Total time elapsed: 10507.546781 sec. Average time per batch: 2.728524 sec
#
# ========== EPOCH 14 ==========
# 	iter = 3900, local_loss (cur) = 92.863953, local_loss (avg) = 80.610124, kl = 0.000387
#
# 	Total time elapsed: 10643.707622 sec. Average time per batch: 2.728456 sec
#
# 	iter = 3950, local_loss (cur) = 57.349064, local_loss (avg) = 80.377513, kl = 0.000873
#
# 	Total time elapsed: 10780.136253 sec. Average time per batch: 2.728458 sec
#
# 	iter = 4000, local_loss (cur) = 65.697357, local_loss (avg) = 80.230712, kl = 0.000521
#
# 	Total time elapsed: 10916.751440 sec. Average time per batch: 2.728506 sec
#
# Saving checkpoint with train loss 65
# 	iter = 4050, local_loss (cur) = 89.414185, local_loss (avg) = 80.322547, kl = 0.001946
#
# 	Total time elapsed: 11053.873961 sec. Average time per batch: 2.728678 sec
#
# 	iter = 4100, local_loss (cur) = 56.823940, local_loss (avg) = 80.087560, kl = 0.001387
#
# 	Total time elapsed: 11190.682135 sec. Average time per batch: 2.728769 sec
# /home/eko/anaconda2/lib/python2.7/site-packages/pretty_midi/pretty_midi.py:890: RuntimeWarning: invalid value encountered in divide
#   synthesized /= np.abs(synthesized).max()
# Saving checkpoint with train loss 56
# 	iter = 4150, local_loss (cur) = 57.789780, local_loss (avg) = 79.864583, kl = 0.000648
#
# 	Total time elapsed: 11326.900548 sec. Average time per batch: 2.728716 sec
#
# ========== EPOCH 15 ==========
# 	iter = 4200, local_loss (cur) = 68.425217, local_loss (avg) = 79.750189, kl = 0.000406
#
# 	Total time elapsed: 11463.729300 sec. Average time per batch: 2.728810 sec
#
# 	iter = 4250, local_loss (cur) = 89.036041, local_loss (avg) = 79.843048, kl = 0.001378
#
# 	Total time elapsed: 11600.151801 sec. Average time per batch: 2.728805 sec
#
# 	iter = 4300, local_loss (cur) = 50.073235, local_loss (avg) = 79.545349, kl = 0.000843
#
# 	Total time elapsed: 11737.583509 sec. Average time per batch: 2.729036 sec
#
# Saving checkpoint with train loss 50
# 	iter = 4350, local_loss (cur) = 62.562973, local_loss (avg) = 79.375526, kl = 0.001677
#
# 	Total time elapsed: 11874.792936 sec. Average time per batch: 2.729210 sec
#
# 	iter = 4400, local_loss (cur) = 85.216888, local_loss (avg) = 79.433939, kl = 0.000431
#
# 	Total time elapsed: 12011.772108 sec. Average time per batch: 2.729328 sec
#
# ========== EPOCH 16 ==========
# 	iter = 4450, local_loss (cur) = 62.046341, local_loss (avg) = 79.260063, kl = 0.000362
#
# 	Total time elapsed: 12147.510047 sec. Average time per batch: 2.729164 sec
#
# 	iter = 4500, local_loss (cur) = 64.334320, local_loss (avg) = 79.110806, kl = 0.000318
#
# 	Total time elapsed: 12283.933272 sec. Average time per batch: 2.729156 sec
#
# 	iter = 4550, local_loss (cur) = 54.749344, local_loss (avg) = 78.867191, kl = 0.000484
#
# 	Total time elapsed: 12420.018374 sec. Average time per batch: 2.729075 sec
#
# 	iter = 4600, local_loss (cur) = 43.929085, local_loss (avg) = 78.517810, kl = 0.000710
#
# 	Total time elapsed: 12556.380257 sec. Average time per batch: 2.729055 sec
#
# Saving checkpoint with train loss 43
# 	iter = 4650, local_loss (cur) = 99.051422, local_loss (avg) = 78.723146, kl = 0.000992
#
# 	Total time elapsed: 12694.230748 sec. Average time per batch: 2.729355 sec
#
# 	iter = 4700, local_loss (cur) = 89.008308, local_loss (avg) = 78.825998, kl = 0.000351
#
# 	Total time elapsed: 12830.887626 sec. Average time per batch: 2.729395 sec
#
# ========== EPOCH 17 ==========
# 	iter = 4750, local_loss (cur) = 55.350761, local_loss (avg) = 78.591246, kl = 0.002291
#
# 	Total time elapsed: 12967.081339 sec. Average time per batch: 2.729337 sec
#
# 	iter = 4800, local_loss (cur) = 57.287338, local_loss (avg) = 78.378206, kl = 0.000870
#
# 	Total time elapsed: 13103.009933 sec. Average time per batch: 2.729225 sec
#
# 	iter = 4850, local_loss (cur) = 64.538506, local_loss (avg) = 78.239809, kl = 0.000869
#
# 	Total time elapsed: 13239.421543 sec. Average time per batch: 2.729215 sec
#
# 	iter = 4900, local_loss (cur) = 59.896477, local_loss (avg) = 78.056376, kl = 0.002583
#
# 	Total time elapsed: 13375.974782 sec. Average time per batch: 2.729234 sec
#
# 	iter = 4950, local_loss (cur) = 62.376877, local_loss (avg) = 77.899581, kl = 0.000571
#
# 	Total time elapsed: 13512.600293 sec. Average time per batch: 2.729267 sec
#
# 	iter = 5000, local_loss (cur) = 47.720879, local_loss (avg) = 77.597794, kl = 0.000406
#
# 	Total time elapsed: 13649.614586 sec. Average time per batch: 2.729377 sec
#
# ========== EPOCH 18 ==========
# 	iter = 5050, local_loss (cur) = 59.297401, local_loss (avg) = 77.414790, kl = 0.000288
#
# 	Total time elapsed: 13786.176334 sec. Average time per batch: 2.729395 sec
#
# 	iter = 5100, local_loss (cur) = 90.857277, local_loss (avg) = 77.549215, kl = 0.000591
#
# 	Total time elapsed: 13922.229481 sec. Average time per batch: 2.729314 sec
#
# 	iter = 5150, local_loss (cur) = 79.383499, local_loss (avg) = 77.567558, kl = 0.001770
#
# 	Total time elapsed: 14058.375743 sec. Average time per batch: 2.729252 sec
#
# 	iter = 5200, local_loss (cur) = 56.670662, local_loss (avg) = 77.358589, kl = 0.000539
#
# 	Total time elapsed: 14194.916694 sec. Average time per batch: 2.729267 sec
#
# 	iter = 5250, local_loss (cur) = 57.610413, local_loss (avg) = 77.161107, kl = 0.000438
#
# 	Total time elapsed: 14332.131859 sec. Average time per batch: 2.729410 sec
#
# ========== EPOCH 19 ==========
# 	iter = 5300, local_loss (cur) = 51.000839, local_loss (avg) = 76.899504, kl = 0.000880
#
# 	Total time elapsed: 14468.681748 sec. Average time per batch: 2.729425 sec
#
# 	iter = 5350, local_loss (cur) = 50.765537, local_loss (avg) = 76.638165, kl = 0.001129
#
# 	Total time elapsed: 14604.447018 sec. Average time per batch: 2.729293 sec
#
# 	iter = 5400, local_loss (cur) = 60.394005, local_loss (avg) = 76.475723, kl = 0.000369
#
# 	Total time elapsed: 14740.292181 sec. Average time per batch: 2.729178 sec
#
# 	iter = 5450, local_loss (cur) = 47.866074, local_loss (avg) = 76.189627, kl = 0.001794
#
# 	Total time elapsed: 14876.873310 sec. Average time per batch: 2.729201 sec
#
# 	iter = 5500, local_loss (cur) = 56.273586, local_loss (avg) = 75.990466, kl = 0.000627
#
# 	Total time elapsed: 15013.634727 sec. Average time per batch: 2.729256 sec
#
# 	iter = 5550, local_loss (cur) = 36.389351, local_loss (avg) = 75.594455, kl = 0.000433
#
# 	Total time elapsed: 15149.667700 sec. Average time per batch: 2.729178 sec
#
# ========== EPOCH 20 ==========
# 	iter = 5600, local_loss (cur) = 45.201164, local_loss (avg) = 75.290522, kl = 0.000391
#
# 	Total time elapsed: 15285.635863 sec. Average time per batch: 2.729090 sec
#
# 	iter = 5650, local_loss (cur) = 48.501610, local_loss (avg) = 75.022633, kl = 0.001217
#
# 	Total time elapsed: 15421.933106 sec. Average time per batch: 2.729063 sec
#
# 	iter = 5700, local_loss (cur) = 45.780220, local_loss (avg) = 74.730209, kl = 0.000911
#
# 	Total time elapsed: 15558.518041 sec. Average time per batch: 2.729086 sec
#
# 	iter = 5750, local_loss (cur) = 39.208900, local_loss (avg) = 74.374996, kl = 0.000807
#
# 	Total time elapsed: 15695.688154 sec. Average time per batch: 2.729210 sec
#
# 	iter = 5800, local_loss (cur) = 39.215080, local_loss (avg) = 74.023397, kl = 0.000641
#
# 	Total time elapsed: 15831.576695 sec. Average time per batch: 2.729112 sec
#
# Saving checkpoint with train loss 39
# ========== EPOCH 21 ==========
# 	iter = 5850, local_loss (cur) = 74.661346, local_loss (avg) = 74.029776, kl = 0.000661
#
# 	Total time elapsed: 15968.057428 sec. Average time per batch: 2.729116 sec
#
# 	iter = 5900, local_loss (cur) = 93.610016, local_loss (avg) = 74.225579, kl = 0.000584
#
# 	Total time elapsed: 16103.752726 sec. Average time per batch: 2.728987 sec
#
# 	iter = 5950, local_loss (cur) = 49.419540, local_loss (avg) = 73.977518, kl = 0.000534
#
# 	Total time elapsed: 16240.457523 sec. Average time per batch: 2.729030 sec
#
# 	iter = 6000, local_loss (cur) = 20.825001, local_loss (avg) = 73.445993, kl = 0.001157
#
# 	Total time elapsed: 16376.266062 sec. Average time per batch: 2.728923 sec
#
# Saving checkpoint with train loss 20
# 	iter = 6050, local_loss (cur) = 65.114853, local_loss (avg) = 73.362682, kl = 0.000790
#
# 	Total time elapsed: 16512.735920 sec. Average time per batch: 2.728927 sec
#
# 	iter = 6100, local_loss (cur) = 57.515385, local_loss (avg) = 73.204209, kl = 0.000582
#
# 	Total time elapsed: 16648.554579 sec. Average time per batch: 2.728824 sec
#
# ========== EPOCH 22 ==========
# 	iter = 6150, local_loss (cur) = 64.857338, local_loss (avg) = 73.120740, kl = 0.000308
#
# 	Total time elapsed: 16784.678775 sec. Average time per batch: 2.728772 sec
#
# 	iter = 6200, local_loss (cur) = 52.051964, local_loss (avg) = 72.910052, kl = 0.001934
#
# 	Total time elapsed: 16920.728247 sec. Average time per batch: 2.728710 sec
#
# 	iter = 6250, local_loss (cur) = 54.274521, local_loss (avg) = 72.723697, kl = 0.001420
#
# 	Total time elapsed: 17058.067691 sec. Average time per batch: 2.728854 sec
#
# 	iter = 6300, local_loss (cur) = 56.060760, local_loss (avg) = 72.557068, kl = 0.001012
#
# 	Total time elapsed: 17194.767358 sec. Average time per batch: 2.728895 sec
#
# 	iter = 6350, local_loss (cur) = 52.553043, local_loss (avg) = 72.357027, kl = 0.000554
#
# 	Total time elapsed: 17330.820746 sec. Average time per batch: 2.728833 sec
#
# ========== EPOCH 23 ==========
# 	iter = 6400, local_loss (cur) = 50.348717, local_loss (avg) = 72.136944, kl = 0.000298
#
# 	Total time elapsed: 17467.145232 sec. Average time per batch: 2.728815 sec
#
# 	iter = 6450, local_loss (cur) = 61.784008, local_loss (avg) = 72.033415, kl = 0.000486
#
# 	Total time elapsed: 17603.821704 sec. Average time per batch: 2.728852 sec
#
# 	iter = 6500, local_loss (cur) = 40.788918, local_loss (avg) = 71.720970, kl = 0.000610
#
# 	Total time elapsed: 17740.232452 sec. Average time per batch: 2.728847 sec
#
# 	iter = 6550, local_loss (cur) = 38.174881, local_loss (avg) = 71.385509, kl = 0.002732
#
# 	Total time elapsed: 17876.032451 sec. Average time per batch: 2.728749 sec
#
# 	iter = 6600, local_loss (cur) = 47.429848, local_loss (avg) = 71.145952, kl = 0.001127
#
# 	Total time elapsed: 18012.635560 sec. Average time per batch: 2.728774 sec
#
# 	iter = 6650, local_loss (cur) = 41.927147, local_loss (avg) = 70.853764, kl = 0.000386
#
# 	Total time elapsed: 18148.704849 sec. Average time per batch: 2.728718 sec
#
# ========== EPOCH 24 ==========
# 	iter = 6700, local_loss (cur) = 31.516117, local_loss (avg) = 70.460388, kl = 0.001432
#
# 	Total time elapsed: 18284.613691 sec. Average time per batch: 2.728640 sec
#
# 	iter = 6750, local_loss (cur) = 73.259506, local_loss (avg) = 70.488379, kl = 0.002258
#
# 	Total time elapsed: 18420.899236 sec. Average time per batch: 2.728618 sec
#
# 	iter = 6800, local_loss (cur) = 37.553722, local_loss (avg) = 70.159032, kl = 0.003051
#
# 	Total time elapsed: 18557.926395 sec. Average time per batch: 2.728706 sec
#
# 	iter = 6850, local_loss (cur) = 78.562088, local_loss (avg) = 70.243063, kl = 0.000854
#
# 	Total time elapsed: 18694.253137 sec. Average time per batch: 2.728690 sec
#
# 	iter = 6900, local_loss (cur) = 39.893742, local_loss (avg) = 69.939570, kl = 0.000675
#
# 	Total time elapsed: 18831.262422 sec. Average time per batch: 2.728773 sec
#
# ========== EPOCH 25 ==========
# 	iter = 6950, local_loss (cur) = 50.546902, local_loss (avg) = 69.745643, kl = 0.000591
#
# 	Total time elapsed: 18966.698930 sec. Average time per batch: 2.728629 sec
#
# 	iter = 7000, local_loss (cur) = 35.602184, local_loss (avg) = 69.404209, kl = 0.000571
#
# 	Total time elapsed: 19103.203644 sec. Average time per batch: 2.728639 sec
#
# 	iter = 7050, local_loss (cur) = 35.875252, local_loss (avg) = 69.068919, kl = 0.000866
#
# 	Total time elapsed: 19239.468190 sec. Average time per batch: 2.728616 sec
#
# 	iter = 7100, local_loss (cur) = 43.279434, local_loss (avg) = 68.811024, kl = 0.001206
#
# 	Total time elapsed: 19375.659017 sec. Average time per batch: 2.728582 sec
#
# 	iter = 7150, local_loss (cur) = 43.830231, local_loss (avg) = 68.561216, kl = 0.000689
#
# 	Total time elapsed: 19512.441550 sec. Average time per batch: 2.728631 sec
#
# 	iter = 7200, local_loss (cur) = 35.088451, local_loss (avg) = 68.226489, kl = 0.000898
#
# 	Total time elapsed: 19649.514434 sec. Average time per batch: 2.728720 sec
#
# ========== EPOCH 26 ==========
# 	iter = 7250, local_loss (cur) = 39.953369, local_loss (avg) = 67.943757, kl = 0.001616
#
# 	Total time elapsed: 19785.844194 sec. Average time per batch: 2.728706 sec
#
# 	iter = 7300, local_loss (cur) = 46.201473, local_loss (avg) = 67.726335, kl = 0.001175
#
# 	Total time elapsed: 19922.368070 sec. Average time per batch: 2.728718 sec
#
# 	iter = 7350, local_loss (cur) = 34.443081, local_loss (avg) = 67.393502, kl = 0.003723
#
# 	Total time elapsed: 20059.309697 sec. Average time per batch: 2.728787 sec
#
# 	iter = 7400, local_loss (cur) = 44.584122, local_loss (avg) = 67.165408, kl = 0.004316
#
# 	Total time elapsed: 20195.810478 sec. Average time per batch: 2.728795 sec
#
# 	iter = 7450, local_loss (cur) = 47.198536, local_loss (avg) = 66.965739, kl = 0.002378
#
# 	Total time elapsed: 20332.682015 sec. Average time per batch: 2.728853 sec
#
# 	iter = 7500, local_loss (cur) = 57.317570, local_loss (avg) = 66.869258, kl = 0.000669
#
# 	Total time elapsed: 20469.079815 sec. Average time per batch: 2.728847 sec
#
# ========== EPOCH 27 ==========
# 	iter = 7550, local_loss (cur) = 36.178421, local_loss (avg) = 66.562349, kl = 0.000492
#
# 	Total time elapsed: 20606.042342 sec. Average time per batch: 2.728916 sec
#
# 	iter = 7600, local_loss (cur) = 40.518013, local_loss (avg) = 66.301906, kl = 0.000592
#
# 	Total time elapsed: 20742.764136 sec. Average time per batch: 2.728952 sec
#
# 	iter = 7650, local_loss (cur) = 31.868528, local_loss (avg) = 65.957572, kl = 0.001073
#
# 	Total time elapsed: 20879.461164 sec. Average time per batch: 2.728985 sec
#
# 	iter = 7700, local_loss (cur) = 37.508789, local_loss (avg) = 65.673084, kl = 0.001373
#
# 	Total time elapsed: 21016.023009 sec. Average time per batch: 2.728999 sec
#
# 	iter = 7750, local_loss (cur) = 32.822006, local_loss (avg) = 65.344574, kl = 0.000696
#
# 	Total time elapsed: 21151.440821 sec. Average time per batch: 2.728866 sec
#
# ========== EPOCH 28 ==========
# 	iter = 7800, local_loss (cur) = 37.535866, local_loss (avg) = 65.066487, kl = 0.001194
#
# 	Total time elapsed: 21287.540417 sec. Average time per batch: 2.728822 sec
#
# 	iter = 7850, local_loss (cur) = 51.368011, local_loss (avg) = 64.929502, kl = 0.001069
#
# 	Total time elapsed: 21424.194881 sec. Average time per batch: 2.728849 sec
#
# 	iter = 7900, local_loss (cur) = 42.274750, local_loss (avg) = 64.702954, kl = 0.000570
#
# 	Total time elapsed: 21560.119791 sec. Average time per batch: 2.728784 sec
#
# 	iter = 7950, local_loss (cur) = 32.409332, local_loss (avg) = 64.380018, kl = 0.003654
#
# 	Total time elapsed: 21696.522023 sec. Average time per batch: 2.728779 sec
#
# 	iter = 8000, local_loss (cur) = 30.853313, local_loss (avg) = 64.044751, kl = 0.001167
#
# 	Total time elapsed: 21832.069675 sec. Average time per batch: 2.728668 sec
#
# 	iter = 8050, local_loss (cur) = 29.886669, local_loss (avg) = 63.703170, kl = 0.000789
#
# 	Total time elapsed: 21967.637899 sec. Average time per batch: 2.728560 sec
#
# ========== EPOCH 29 ==========
# 	iter = 8100, local_loss (cur) = 39.678661, local_loss (avg) = 63.462925, kl = 0.000544
#
# 	Total time elapsed: 22103.724189 sec. Average time per batch: 2.728518 sec
#
# 	iter = 8150, local_loss (cur) = 36.342636, local_loss (avg) = 63.191722, kl = 0.001149
#
# 	Total time elapsed: 22239.798110 sec. Average time per batch: 2.728475 sec
#
# 	iter = 8200, local_loss (cur) = 39.089668, local_loss (avg) = 62.950702, kl = 0.001682
#
# 	Total time elapsed: 22375.940155 sec. Average time per batch: 2.728440 sec
#
# 	iter = 8250, local_loss (cur) = 42.068630, local_loss (avg) = 62.741881, kl = 0.001581
#
# 	Total time elapsed: 22513.774445 sec. Average time per batch: 2.728612 sec
#
# 	iter = 8300, local_loss (cur) = 32.125923, local_loss (avg) = 62.435721, kl = 0.000803
#
# 	Total time elapsed: 22650.719017 sec. Average time per batch: 2.728674 sec
#
# ========== EPOCH 30 ==========
# 	iter = 8350, local_loss (cur) = 27.234898, local_loss (avg) = 62.083713, kl = 0.000622
#
# 	Total time elapsed: 22786.666150 sec. Average time per batch: 2.728615 sec
#
# 	iter = 8400, local_loss (cur) = 40.542336, local_loss (avg) = 61.868299, kl = 0.001180
#
# 	Total time elapsed: 22922.624649 sec. Average time per batch: 2.728559 sec
#
# 	iter = 8450, local_loss (cur) = 39.446037, local_loss (avg) = 61.644077, kl = 0.000675
#
# 	Total time elapsed: 23058.304236 sec. Average time per batch: 2.728471 sec
#
# 	iter = 8500, local_loss (cur) = 5.601936, local_loss (avg) = 61.083655, kl = 0.001246
#
# 	Total time elapsed: 23195.359646 sec. Average time per batch: 2.728545 sec
#
# Saving checkpoint with train loss 5
# 	iter = 8550, local_loss (cur) = 22.336178, local_loss (avg) = 60.696181, kl = 0.001784
#
# 	Total time elapsed: 23332.442599 sec. Average time per batch: 2.728622 sec
#
# 	iter = 8600, local_loss (cur) = 49.620255, local_loss (avg) = 60.585421, kl = 0.000509
#
# 	Total time elapsed: 23468.297655 sec. Average time per batch: 2.728555 sec
#
# ========== EPOCH 31 ==========
# 	iter = 8650, local_loss (cur) = 43.161018, local_loss (avg) = 60.411177, kl = 0.001415
#
# 	Total time elapsed: 23604.356756 sec. Average time per batch: 2.728512 sec
#
# 	iter = 8700, local_loss (cur) = 28.880091, local_loss (avg) = 60.095866, kl = 0.001502
#
# 	Total time elapsed: 23740.668600 sec. Average time per batch: 2.728499 sec
#
# 	iter = 8750, local_loss (cur) = 41.484886, local_loss (avg) = 59.909757, kl = 0.000918
#
# 	Total time elapsed: 23877.019841 sec. Average time per batch: 2.728490 sec
#
# 	iter = 8800, local_loss (cur) = 53.781986, local_loss (avg) = 59.848479, kl = 0.000777
#
# 	Total time elapsed: 24012.958429 sec. Average time per batch: 2.728435 sec
#
# 	iter = 8850, local_loss (cur) = 36.866055, local_loss (avg) = 59.618655, kl = 0.000924
#
# 	Total time elapsed: 24149.107111 sec. Average time per batch: 2.728404 sec
#
# ========== EPOCH 32 ==========
# 	iter = 8900, local_loss (cur) = 35.940437, local_loss (avg) = 59.381872, kl = 0.000823
#
# 	Total time elapsed: 24286.070774 sec. Average time per batch: 2.728465 sec
#
# 	iter = 8950, local_loss (cur) = 39.186005, local_loss (avg) = 59.179914, kl = 0.002915
#
# 	Total time elapsed: 24422.729784 sec. Average time per batch: 2.728492 sec
#
# 	iter = 9000, local_loss (cur) = 33.809456, local_loss (avg) = 58.926209, kl = 0.001732
#
# 	Total time elapsed: 24558.431373 sec. Average time per batch: 2.728411 sec
#
# 	iter = 9050, local_loss (cur) = 55.843369, local_loss (avg) = 58.895381, kl = 0.001613
#
# 	Total time elapsed: 24695.177240 sec. Average time per batch: 2.728447 sec
#
# 	iter = 9100, local_loss (cur) = 48.848034, local_loss (avg) = 58.794907, kl = 0.001228
#
# 	Total time elapsed: 24830.995160 sec. Average time per batch: 2.728381 sec
#
# 	iter = 9150, local_loss (cur) = 35.040344, local_loss (avg) = 58.557362, kl = 0.000852
#
# 	Total time elapsed: 24966.419444 sec. Average time per batch: 2.728272 sec
#
# ========== EPOCH 33 ==========
# 	iter = 9200, local_loss (cur) = 40.482643, local_loss (avg) = 58.376615, kl = 0.001150
#
# 	Total time elapsed: 25103.058079 sec. Average time per batch: 2.728297 sec
#
# 	iter = 9250, local_loss (cur) = 38.824322, local_loss (avg) = 58.181092, kl = 0.002282
#
# 	Total time elapsed: 25239.117942 sec. Average time per batch: 2.728258 sec
#
# 	iter = 9300, local_loss (cur) = 37.896957, local_loss (avg) = 57.978250, kl = 0.000831
#
# 	Total time elapsed: 25376.215534 sec. Average time per batch: 2.728332 sec
#
# 	iter = 9350, local_loss (cur) = 35.919033, local_loss (avg) = 57.757658, kl = 0.001404
#
# 	Total time elapsed: 25513.124059 sec. Average time per batch: 2.728385 sec
#
# 	iter = 9400, local_loss (cur) = 31.913490, local_loss (avg) = 57.499216, kl = 0.002715
#
# 	Total time elapsed: 25649.190055 sec. Average time per batch: 2.728347 sec
#
# 	iter = 9450, local_loss (cur) = 41.966202, local_loss (avg) = 57.343886, kl = 0.002513
#
# 	Total time elapsed: 25786.414095 sec. Average time per batch: 2.728432 sec
#
# ========== EPOCH 34 ==========
# 	iter = 9500, local_loss (cur) = 32.563637, local_loss (avg) = 57.096084, kl = 0.000696
#
# 	Total time elapsed: 25922.909741 sec. Average time per batch: 2.728440 sec
#
# 	iter = 9550, local_loss (cur) = 42.034538, local_loss (avg) = 56.945468, kl = 0.000844
#
# 	Total time elapsed: 26058.531641 sec. Average time per batch: 2.728356 sec
#
# 	iter = 9600, local_loss (cur) = 45.497574, local_loss (avg) = 56.830989, kl = 0.001028
#
# 	Total time elapsed: 26194.005097 sec. Average time per batch: 2.728258 sec
#
# 	iter = 9650, local_loss (cur) = 39.037025, local_loss (avg) = 56.653050, kl = 0.001358
#
# 	Total time elapsed: 26329.653414 sec. Average time per batch: 2.728179 sec
#
# 	iter = 9700, local_loss (cur) = 34.608482, local_loss (avg) = 56.432604, kl = 0.001319
#
# 	Total time elapsed: 26465.586037 sec. Average time per batch: 2.728130 sec
#
# ========== EPOCH 35 ==========
# 	iter = 9750, local_loss (cur) = 22.052485, local_loss (avg) = 56.088803, kl = 0.002255
#
# 	Total time elapsed: 26601.760676 sec. Average time per batch: 2.728106 sec
#
# 	iter = 9800, local_loss (cur) = 46.263626, local_loss (avg) = 55.990551, kl = 0.001292
#
# 	Total time elapsed: 26738.046547 sec. Average time per batch: 2.728094 sec
#
# 	iter = 9850, local_loss (cur) = 43.780094, local_loss (avg) = 55.868447, kl = 0.001547
#
# 	Total time elapsed: 26873.864026 sec. Average time per batch: 2.728034 sec
#
# 	iter = 9900, local_loss (cur) = 54.794090, local_loss (avg) = 55.857703, kl = 0.002049
#
# 	Total time elapsed: 27010.742396 sec. Average time per batch: 2.728082 sec
#
# 	iter = 9950, local_loss (cur) = 44.796329, local_loss (avg) = 55.747089, kl = 0.000647
#
# 	Total time elapsed: 27146.906188 sec. Average time per batch: 2.728058 sec
#
# 	iter = 10000, local_loss (cur) = 31.681187, local_loss (avg) = 55.506430, kl = 0.000520
#
# 	Total time elapsed: 27283.212732 sec. Average time per batch: 2.728048 sec
#
# ========== EPOCH 36 ==========
# 	iter = 10050, local_loss (cur) = 26.478479, local_loss (avg) = 55.216151, kl = 0.000931
#
# 	Total time elapsed: 27419.621120 sec. Average time per batch: 2.728049 sec
#
# 	iter = 10100, local_loss (cur) = 32.176502, local_loss (avg) = 54.985754, kl = 0.005601
#
# 	Total time elapsed: 27556.015107 sec. Average time per batch: 2.728048 sec
#
# 	iter = 10150, local_loss (cur) = 16.282887, local_loss (avg) = 54.598726, kl = 0.001394
#
# 	Total time elapsed: 27692.602158 sec. Average time per batch: 2.728066 sec
#
# 	iter = 10200, local_loss (cur) = 37.940437, local_loss (avg) = 54.432143, kl = 0.003710
#
# 	Total time elapsed: 27828.922361 sec. Average time per batch: 2.728058 sec
#
# 	iter = 10250, local_loss (cur) = 34.434387, local_loss (avg) = 54.232165, kl = 0.001012
#
# 	Total time elapsed: 27964.395173 sec. Average time per batch: 2.727968 sec
#
# ========== EPOCH 37 ==========
# 	iter = 10300, local_loss (cur) = 33.168312, local_loss (avg) = 54.021527, kl = 0.001889
#
# 	Total time elapsed: 28100.631127 sec. Average time per batch: 2.727952 sec
#
# 	iter = 10350, local_loss (cur) = 32.597752, local_loss (avg) = 53.807289, kl = 0.001051
#
# 	Total time elapsed: 28236.633271 sec. Average time per batch: 2.727914 sec
#
# 	iter = 10400, local_loss (cur) = 30.442291, local_loss (avg) = 53.573639, kl = 0.001289
#
# 	Total time elapsed: 28373.501757 sec. Average time per batch: 2.727959 sec
#
# 	iter = 10450, local_loss (cur) = 7.014882, local_loss (avg) = 53.108051, kl = 0.001189
#
# 	Total time elapsed: 28509.311268 sec. Average time per batch: 2.727903 sec
#
# 	iter = 10500, local_loss (cur) = 16.978111, local_loss (avg) = 52.746752, kl = 0.001289
#
# 	Total time elapsed: 28645.917245 sec. Average time per batch: 2.727923 sec
#
# 	iter = 10550, local_loss (cur) = 33.143612, local_loss (avg) = 52.550720, kl = 0.000906
#
# 	Total time elapsed: 28781.965121 sec. Average time per batch: 2.727890 sec
#
# ========== EPOCH 38 ==========
# 	iter = 10600, local_loss (cur) = 35.369804, local_loss (avg) = 52.378911, kl = 0.001165
#
# 	Total time elapsed: 28917.953977 sec. Average time per batch: 2.727852 sec
#
# 	iter = 10650, local_loss (cur) = 38.501060, local_loss (avg) = 52.240133, kl = 0.002444
#
# 	Total time elapsed: 29053.161324 sec. Average time per batch: 2.727740 sec
#
# 	iter = 10700, local_loss (cur) = 50.765640, local_loss (avg) = 52.225388, kl = 0.001103
#
# 	Total time elapsed: 29189.330875 sec. Average time per batch: 2.727720 sec
#
# 	iter = 10750, local_loss (cur) = 37.366341, local_loss (avg) = 52.076797, kl = 0.000827
#
# 	Total time elapsed: 29325.365672 sec. Average time per batch: 2.727687 sec
#
# 	iter = 10800, local_loss (cur) = 33.096397, local_loss (avg) = 51.886993, kl = 0.001216
#
# 	Total time elapsed: 29461.368310 sec. Average time per batch: 2.727652 sec
#
# ========== EPOCH 39 ==========
# 	iter = 10850, local_loss (cur) = 38.072319, local_loss (avg) = 51.748847, kl = 0.000716
#
# 	Total time elapsed: 29597.725474 sec. Average time per batch: 2.727650 sec
#
# 	iter = 10900, local_loss (cur) = 21.380720, local_loss (avg) = 51.445165, kl = 0.001476
#
# 	Total time elapsed: 29734.268683 sec. Average time per batch: 2.727664 sec
#
# 	iter = 10950, local_loss (cur) = 32.555595, local_loss (avg) = 51.256270, kl = 0.001508
#
# 	Total time elapsed: 29870.011755 sec. Average time per batch: 2.727606 sec
#
# 	iter = 11000, local_loss (cur) = 7.917289, local_loss (avg) = 50.822880, kl = 0.005591
#
# 	Total time elapsed: 30006.284076 sec. Average time per batch: 2.727596 sec
#
# 	iter = 11050, local_loss (cur) = 13.640479, local_loss (avg) = 50.451056, kl = 0.000900
#
# 	Total time elapsed: 30142.943008 sec. Average time per batch: 2.727621 sec
#
# 	iter = 11100, local_loss (cur) = 27.931763, local_loss (avg) = 50.225863, kl = 0.000564
#
# 	Total time elapsed: 30279.280227 sec. Average time per batch: 2.727617 sec
#
# ========== EPOCH 40 ==========
# 	iter = 11150, local_loss (cur) = 40.269260, local_loss (avg) = 50.126297, kl = 0.001759
#
# 	Total time elapsed: 30415.698637 sec. Average time per batch: 2.727621 sec
#
# 	iter = 11200, local_loss (cur) = 38.626358, local_loss (avg) = 50.011298, kl = 0.001950
#
# 	Total time elapsed: 30552.079375 sec. Average time per batch: 2.727621 sec
#
# 	iter = 11250, local_loss (cur) = 23.105886, local_loss (avg) = 49.742243, kl = 0.000624
#
# 	Total time elapsed: 30688.485665 sec. Average time per batch: 2.727623 sec
#
# 	iter = 11300, local_loss (cur) = 34.846039, local_loss (avg) = 49.593281, kl = 0.000981
#
# 	Total time elapsed: 30823.375909 sec. Average time per batch: 2.727491 sec
#
# 	iter = 11350, local_loss (cur) = 42.913467, local_loss (avg) = 49.526483, kl = 0.008842
#
# 	Total time elapsed: 30959.701432 sec. Average time per batch: 2.727487 sec
#
# ========== EPOCH 41 ==========
# 	iter = 11400, local_loss (cur) = 27.770412, local_loss (avg) = 49.308923, kl = 0.001012
#
# 	Total time elapsed: 31095.470231 sec. Average time per batch: 2.727434 sec
#
# 	iter = 11450, local_loss (cur) = 31.232603, local_loss (avg) = 49.128159, kl = 0.001107
#
# 	Total time elapsed: 31232.120458 sec. Average time per batch: 2.727458 sec
#
# 	iter = 11500, local_loss (cur) = 32.638054, local_loss (avg) = 48.963258, kl = 0.000991
#
# 	Total time elapsed: 31367.928402 sec. Average time per batch: 2.727409 sec
#
# 	iter = 11550, local_loss (cur) = 24.443439, local_loss (avg) = 48.718060, kl = 0.008963
#
# 	Total time elapsed: 31503.667813 sec. Average time per batch: 2.727354 sec
#
# 	iter = 11600, local_loss (cur) = 59.551659, local_loss (avg) = 48.826396, kl = 0.000871
#
# 	Total time elapsed: 31640.240424 sec. Average time per batch: 2.727372 sec
#
# 	iter = 11650, local_loss (cur) = 56.685581, local_loss (avg) = 48.904988, kl = 0.000730
#
# 	Total time elapsed: 31776.611009 sec. Average time per batch: 2.727372 sec
#
# ========== EPOCH 42 ==========
# 	iter = 11700, local_loss (cur) = 31.512657, local_loss (avg) = 48.731065, kl = 0.003694
#
# 	Total time elapsed: 31913.768851 sec. Average time per batch: 2.727439 sec
#
# 	iter = 11750, local_loss (cur) = 26.092560, local_loss (avg) = 48.504680, kl = 0.001281
#
# 	Total time elapsed: 32049.859696 sec. Average time per batch: 2.727416 sec
#
# 	iter = 11800, local_loss (cur) = 26.170948, local_loss (avg) = 48.281342, kl = 0.001038
#
# 	Total time elapsed: 32185.965246 sec. Average time per batch: 2.727393 sec
#
# 	iter = 11850, local_loss (cur) = 25.953903, local_loss (avg) = 48.058068, kl = 0.001846
#
# 	Total time elapsed: 32321.514138 sec. Average time per batch: 2.727324 sec
#
# 	iter = 11900, local_loss (cur) = 39.534882, local_loss (avg) = 47.972836, kl = 0.008419
#
# 	Total time elapsed: 32457.311662 sec. Average time per batch: 2.727276 sec
#
# 	iter = 11950, local_loss (cur) = 14.710443, local_loss (avg) = 47.640212, kl = 0.001853
#
# 	Total time elapsed: 32593.083026 sec. Average time per batch: 2.727226 sec
#
# ========== EPOCH 43 ==========
# 	iter = 12000, local_loss (cur) = 29.460747, local_loss (avg) = 47.458417, kl = 0.001970
#
# 	Total time elapsed: 32729.626564 sec. Average time per batch: 2.727242 sec
#
# 	iter = 12050, local_loss (cur) = 58.335144, local_loss (avg) = 47.567185, kl = 0.001427
#
# 	Total time elapsed: 32865.862977 sec. Average time per batch: 2.727231 sec
#
# 	iter = 12100, local_loss (cur) = 37.186337, local_loss (avg) = 47.463376, kl = 0.002544
#
# 	Total time elapsed: 33001.815950 sec. Average time per batch: 2.727197 sec
#
# 	iter = 12150, local_loss (cur) = 33.919571, local_loss (avg) = 47.327938, kl = 0.001474
#
# 	Total time elapsed: 33136.925423 sec. Average time per batch: 2.727095 sec
#
# 	iter = 12200, local_loss (cur) = 33.779968, local_loss (avg) = 47.192458, kl = 0.001249
#
# 	Total time elapsed: 33273.342244 sec. Average time per batch: 2.727100 sec
#
# ========== EPOCH 44 ==========
# 	iter = 12250, local_loss (cur) = 22.591948, local_loss (avg) = 46.946453, kl = 0.002561
#
# 	Total time elapsed: 33409.392108 sec. Average time per batch: 2.727075 sec
#
# 	iter = 12300, local_loss (cur) = 27.717060, local_loss (avg) = 46.754159, kl = 0.001195
#
# 	Total time elapsed: 33545.531556 sec. Average time per batch: 2.727057 sec
#
# 	iter = 12350, local_loss (cur) = 22.154219, local_loss (avg) = 46.508160, kl = 0.000990
#
# 	Total time elapsed: 33681.024966 sec. Average time per batch: 2.726988 sec
#
# 	iter = 12400, local_loss (cur) = 31.574907, local_loss (avg) = 46.358827, kl = 0.001010
#
# 	Total time elapsed: 33816.948711 sec. Average time per batch: 2.726953 sec
#
# 	iter = 12450, local_loss (cur) = 35.068924, local_loss (avg) = 46.245928, kl = 0.003140
#
# 	Total time elapsed: 33952.003839 sec. Average time per batch: 2.726850 sec
#
# 	iter = 12500, local_loss (cur) = 21.078217, local_loss (avg) = 45.994251, kl = 0.002348
#
# 	Total time elapsed: 34088.762751 sec. Average time per batch: 2.726883 sec
#
# ========== EPOCH 45 ==========
# 	iter = 12550, local_loss (cur) = 25.022238, local_loss (avg) = 45.784531, kl = 0.001835
#
# 	Total time elapsed: 34224.822293 sec. Average time per batch: 2.726860 sec
#
# 	iter = 12600, local_loss (cur) = 25.648640, local_loss (avg) = 45.583172, kl = 0.001224
#
# 	Total time elapsed: 34359.889504 sec. Average time per batch: 2.726759 sec
#
# 	iter = 12650, local_loss (cur) = 11.712167, local_loss (avg) = 45.244462, kl = 0.001293
#
# 	Total time elapsed: 34496.744561 sec. Average time per batch: 2.726800 sec
#
# 	iter = 12700, local_loss (cur) = 19.346241, local_loss (avg) = 44.985480, kl = 0.001091
#
# 	Total time elapsed: 34632.424058 sec. Average time per batch: 2.726748 sec
#
# 	iter = 12750, local_loss (cur) = 23.630362, local_loss (avg) = 44.771929, kl = 0.005070
#
# 	Total time elapsed: 34768.374771 sec. Average time per batch: 2.726717 sec
#
# ========== EPOCH 46 ==========
# 	iter = 12800, local_loss (cur) = 44.434132, local_loss (avg) = 44.768551, kl = 0.000868
#
# 	Total time elapsed: 34905.251222 sec. Average time per batch: 2.726760 sec
#
# 	iter = 12850, local_loss (cur) = 57.224197, local_loss (avg) = 44.893107, kl = 0.003204
#
# 	Total time elapsed: 35040.898024 sec. Average time per batch: 2.726706 sec
#
# 	iter = 12900, local_loss (cur) = 26.458059, local_loss (avg) = 44.708757, kl = 0.001487
#
# 	Total time elapsed: 35176.970522 sec. Average time per batch: 2.726686 sec
#
# 	iter = 12950, local_loss (cur) = 0.170732, local_loss (avg) = 44.263377, kl = 0.003847
#
# 	Total time elapsed: 35312.665835 sec. Average time per batch: 2.726636 sec
#
# 	iter = 13000, local_loss (cur) = 35.505882, local_loss (avg) = 44.175802, kl = 0.002279
#
# 	Total time elapsed: 35449.372182 sec. Average time per batch: 2.726665 sec
#
# 	iter = 13050, local_loss (cur) = 30.815742, local_loss (avg) = 44.042201, kl = 0.000627
#
# 	Total time elapsed: 35585.675541 sec. Average time per batch: 2.726663 sec
#
# ========== EPOCH 47 ==========
# 	iter = 13100, local_loss (cur) = 40.150410, local_loss (avg) = 44.003283, kl = 0.002436
#
# 	Total time elapsed: 35721.594847 sec. Average time per batch: 2.726631 sec
#
# 	iter = 13150, local_loss (cur) = 9.242293, local_loss (avg) = 43.655673, kl = 0.001187
#
# 	Total time elapsed: 35857.902570 sec. Average time per batch: 2.726629 sec
#
# 	iter = 13200, local_loss (cur) = 37.127941, local_loss (avg) = 43.590396, kl = 0.000810
#
# 	Total time elapsed: 35994.510130 sec. Average time per batch: 2.726650 sec
#
# 	iter = 13250, local_loss (cur) = 30.732029, local_loss (avg) = 43.461812, kl = 0.000686
#
# 	Total time elapsed: 36130.023274 sec. Average time per batch: 2.726588 sec
#
# 	iter = 13300, local_loss (cur) = 28.129421, local_loss (avg) = 43.308488, kl = 0.000934
#
# 	Total time elapsed: 36266.122952 sec. Average time per batch: 2.726571 sec
#
# ========== EPOCH 48 ==========
# 	iter = 13350, local_loss (cur) = 36.079308, local_loss (avg) = 43.236197, kl = 0.002540
#
# 	Total time elapsed: 36402.536087 sec. Average time per batch: 2.726577 sec
#
# 	iter = 13400, local_loss (cur) = 35.035728, local_loss (avg) = 43.154192, kl = 0.001037
#
# 	Total time elapsed: 36538.054512 sec. Average time per batch: 2.726517 sec
#
# 	iter = 13450, local_loss (cur) = 22.561615, local_loss (avg) = 42.948266, kl = 0.001228
#
# 	Total time elapsed: 36674.388454 sec. Average time per batch: 2.726518 sec
#
# 	iter = 13500, local_loss (cur) = 6.185557, local_loss (avg) = 42.580639, kl = 0.002300
#
# 	Total time elapsed: 36810.940334 sec. Average time per batch: 2.726534 sec
#
# 	iter = 13550, local_loss (cur) = 27.248451, local_loss (avg) = 42.427317, kl = 0.002384
#
# 	Total time elapsed: 36947.579975 sec. Average time per batch: 2.726557 sec
#
# 	iter = 13600, local_loss (cur) = 28.182344, local_loss (avg) = 42.284867, kl = 0.001309
#
# 	Total time elapsed: 37083.831766 sec. Average time per batch: 2.726552 sec
#
# ========== EPOCH 49 ==========
# 	iter = 13650, local_loss (cur) = 12.815395, local_loss (avg) = 41.990173, kl = 0.003703
#
# 	Total time elapsed: 37220.078933 sec. Average time per batch: 2.726546 sec
#
# 	iter = 13700, local_loss (cur) = 45.544014, local_loss (avg) = 42.025711, kl = 0.002918
#
# 	Total time elapsed: 37356.139749 sec. Average time per batch: 2.726527 sec
#
# ...
#
# 	Total time elapsed: 63248.849509 sec. Average time per batch: 2.732014 sec
#
# 	iter = 23200, local_loss (cur) = 19.937590, local_loss (avg) = 22.622411, kl = 0.001497
#
# 	Total time elapsed: 63386.464204 sec. Average time per batch: 2.732057 sec
#
# 	iter = 23250, local_loss (cur) = 18.747612, local_loss (avg) = 22.583663, kl = 0.003198
#
# 	Total time elapsed: 63523.245453 sec. Average time per batch: 2.732065 sec
#
# 	iter = 23300, local_loss (cur) = 15.628628, local_loss (avg) = 22.514113, kl = 0.002269
#
# 	Total time elapsed: 63660.604024 sec. Average time per batch: 2.732098 sec
#
# 	iter = 23350, local_loss (cur) = 28.327692, local_loss (avg) = 22.572249, kl = 0.002225
#
# 	Total time elapsed: 63797.714341 sec. Average time per batch: 2.732119 sec
#
# ========== EPOCH 84 ==========
# 	iter = 23400, local_loss (cur) = 10.418342, local_loss (avg) = 22.450710, kl = 0.012593
#
# 	Total time elapsed: 63933.755358 sec. Average time per batch: 2.732095 sec
#
# 	iter = 23450, local_loss (cur) = 22.317051, local_loss (avg) = 22.449373, kl = 0.001395
#
# 	Total time elapsed: 64069.560282 sec. Average time per batch: 2.732061 sec
#
# 	iter = 23500, local_loss (cur) = 22.014088, local_loss (avg) = 22.445020, kl = 0.001531
#
# 	Total time elapsed: 64205.367255 sec. Average time per batch: 2.732027 sec
#
# 	iter = 23550, local_loss (cur) = 23.519224, local_loss (avg) = 22.455762, kl = 0.002311
#
# 	Total time elapsed: 64342.720962 sec. Average time per batch: 2.732059 sec
#
# 	iter = 23600, local_loss (cur) = 14.238716, local_loss (avg) = 22.373592, kl = 0.003327
#
# 	Total time elapsed: 64479.451570 sec. Average time per batch: 2.732064 sec
#
# ========== EPOCH 85 ==========
# 	iter = 23650, local_loss (cur) = 4.406757, local_loss (avg) = 22.193923, kl = 0.002422
#
# 	Total time elapsed: 64616.424531 sec. Average time per batch: 2.732080 sec
#
# 	iter = 23700, local_loss (cur) = 8.509989, local_loss (avg) = 22.057084, kl = 0.003577
#
# 	Total time elapsed: 64752.822934 sec. Average time per batch: 2.732071 sec
#
# 	iter = 23750, local_loss (cur) = 24.764381, local_loss (avg) = 22.084157, kl = 0.001746
#
# 	Total time elapsed: 64889.902664 sec. Average time per batch: 2.732091 sec
#
# 	iter = 23800, local_loss (cur) = 43.478657, local_loss (avg) = 22.298102, kl = 0.000737
#
# 	Total time elapsed: 65026.573254 sec. Average time per batch: 2.732094 sec
#
# 	iter = 23850, local_loss (cur) = 20.029022, local_loss (avg) = 22.275411, kl = 0.002035
#
# 	Total time elapsed: 65163.085455 sec. Average time per batch: 2.732090 sec
#
# 	iter = 23900, local_loss (cur) = 10.725731, local_loss (avg) = 22.159914, kl = 0.005060
#
# 	Total time elapsed: 65299.447489 sec. Average time per batch: 2.732080 sec
#
# ========== EPOCH 86 ==========
# 	iter = 23950, local_loss (cur) = 10.200994, local_loss (avg) = 22.040325, kl = 0.002101
#
# 	Total time elapsed: 65435.647066 sec. Average time per batch: 2.732063 sec
#
# 	iter = 24000, local_loss (cur) = 18.900549, local_loss (avg) = 22.008927, kl = 0.002146
#
# 	Total time elapsed: 65572.187402 sec. Average time per batch: 2.732061 sec
#
# 	iter = 24050, local_loss (cur) = 1.500065, local_loss (avg) = 21.803839, kl = 0.001810
#
# 	Total time elapsed: 65707.934773 sec. Average time per batch: 2.732025 sec
#
# 	iter = 24100, local_loss (cur) = 16.407299, local_loss (avg) = 21.749873, kl = 0.001960
#
# 	Total time elapsed: 65844.059344 sec. Average time per batch: 2.732005 sec
#
# 	iter = 24150, local_loss (cur) = 16.029184, local_loss (avg) = 21.692667, kl = 0.001597
#
# 	Total time elapsed: 65980.064751 sec. Average time per batch: 2.731981 sec
#
# ========== EPOCH 87 ==========
# 	iter = 24200, local_loss (cur) = 17.498760, local_loss (avg) = 21.650727, kl = 0.005624
#
# 	Total time elapsed: 66115.849601 sec. Average time per batch: 2.731947 sec
#
# 	iter = 24250, local_loss (cur) = 19.383316, local_loss (avg) = 21.628053, kl = 0.002490
#
# 	Total time elapsed: 66252.110956 sec. Average time per batch: 2.731933 sec
#
# 	iter = 24300, local_loss (cur) = 11.769932, local_loss (avg) = 21.529472, kl = 0.002461
#
# 	Total time elapsed: 66388.963944 sec. Average time per batch: 2.731944 sec
#
# 	iter = 24350, local_loss (cur) = 0.124218, local_loss (avg) = 21.315420, kl = 0.001436
#
# 	Total time elapsed: 66524.955109 sec. Average time per batch: 2.731919 sec
#
# 	iter = 24400, local_loss (cur) = 3.590446, local_loss (avg) = 21.138170, kl = 0.005417
#
# 	Total time elapsed: 66661.084228 sec. Average time per batch: 2.731900 sec
#
# 	iter = 24450, local_loss (cur) = 13.534792, local_loss (avg) = 21.062136, kl = 0.003157
#
# 	Total time elapsed: 66796.981920 sec. Average time per batch: 2.731871 sec
#
# ========== EPOCH 88 ==========
# 	iter = 24500, local_loss (cur) = 19.003843, local_loss (avg) = 21.041553, kl = 0.002340
#
# 	Total time elapsed: 66933.582960 sec. Average time per batch: 2.731871 sec
#
# 	iter = 24550, local_loss (cur) = 23.489960, local_loss (avg) = 21.066037, kl = 0.003534
#
# 	Total time elapsed: 67069.768560 sec. Average time per batch: 2.731855 sec
#
# 	iter = 24600, local_loss (cur) = 16.119255, local_loss (avg) = 21.016569, kl = 0.003773
#
# 	Total time elapsed: 67205.444469 sec. Average time per batch: 2.731818 sec
#
# 	iter = 24650, local_loss (cur) = 19.033409, local_loss (avg) = 20.996738, kl = 0.001843
#
# 	Total time elapsed: 67341.088442 sec. Average time per batch: 2.731779 sec
#
# 	iter = 24700, local_loss (cur) = 12.849289, local_loss (avg) = 20.915263, kl = 0.004171
#
# 	Total time elapsed: 67477.538564 sec. Average time per batch: 2.731774 sec
#
# ========== EPOCH 89 ==========
# 	iter = 24750, local_loss (cur) = 24.195709, local_loss (avg) = 20.948068, kl = 1.330890
#
# 	Total time elapsed: 67613.815333 sec. Average time per batch: 2.731761 sec
#
# 	iter = 24800, local_loss (cur) = 9.616953, local_loss (avg) = 20.834757, kl = 0.100139
#
# 	Total time elapsed: 67749.752321 sec. Average time per batch: 2.731735 sec
#
# 	iter = 24850, local_loss (cur) = 22.840582, local_loss (avg) = 20.854815, kl = 0.007076
#
# 	Total time elapsed: 67886.223932 sec. Average time per batch: 2.731730 sec
#
# 	iter = 24900, local_loss (cur) = 0.238323, local_loss (avg) = 20.648650, kl = 0.008412
#
# 	Total time elapsed: 68022.855470 sec. Average time per batch: 2.731732 sec
#
# 	iter = 24950, local_loss (cur) = 2.843688, local_loss (avg) = 20.470600, kl = 0.003973
#
# 	Total time elapsed: 68159.011743 sec. Average time per batch: 2.731715 sec
#
# 	iter = 25000, local_loss (cur) = 11.417828, local_loss (avg) = 20.380073, kl = 0.003567
#
# 	Total time elapsed: 68295.130084 sec. Average time per batch: 2.731696 sec
#
# ========== EPOCH 90 ==========
# 	iter = 25050, local_loss (cur) = 25.646582, local_loss (avg) = 20.432738, kl = 0.001918
#
# 	Total time elapsed: 68431.548865 sec. Average time per batch: 2.731689 sec
#
# 	iter = 25100, local_loss (cur) = 12.305176, local_loss (avg) = 20.351462, kl = 0.004897
#
# 	Total time elapsed: 68567.410519 sec. Average time per batch: 2.731661 sec
#
# 	iter = 25150, local_loss (cur) = 12.731340, local_loss (avg) = 20.275261, kl = 0.002611
#
# 	Total time elapsed: 68704.482708 sec. Average time per batch: 2.731680 sec
#
# 	iter = 25200, local_loss (cur) = 18.754372, local_loss (avg) = 20.260052, kl = 0.001505
#
# 	Total time elapsed: 68840.828115 sec. Average time per batch: 2.731670 sec
#
# 	iter = 25250, local_loss (cur) = 25.844973, local_loss (avg) = 20.315901, kl = 0.003427
#
# 	Total time elapsed: 68977.263150 sec. Average time per batch: 2.731665 sec
#
# ========== EPOCH 91 ==========
# 	iter = 25300, local_loss (cur) = 12.780210, local_loss (avg) = 20.240544, kl = 0.002123
#
# 	Total time elapsed: 69112.948042 sec. Average time per batch: 2.731629 sec
#
# 	iter = 25350, local_loss (cur) = 10.365957, local_loss (avg) = 20.141798, kl = 0.003438
#
# 	Total time elapsed: 69249.376019 sec. Average time per batch: 2.731623 sec
#
# 	iter = 25400, local_loss (cur) = 19.954550, local_loss (avg) = 20.139926, kl = 0.004244
#
# 	Total time elapsed: 69385.413055 sec. Average time per batch: 2.731602 sec
#
# 	iter = 25450, local_loss (cur) = 13.909285, local_loss (avg) = 20.077619, kl = 0.001563
#
# 	Total time elapsed: 69522.344430 sec. Average time per batch: 2.731615 sec
#
# 	iter = 25500, local_loss (cur) = 26.980740, local_loss (avg) = 20.146651, kl = 0.005902
#
# 	Total time elapsed: 69658.836733 sec. Average time per batch: 2.731612 sec
#
# 	iter = 25550, local_loss (cur) = 30.335392, local_loss (avg) = 20.248538, kl = 0.001657
#
# 	Total time elapsed: 69795.349188 sec. Average time per batch: 2.731609 sec
#
# ========== EPOCH 92 ==========
# 	iter = 25600, local_loss (cur) = 20.843271, local_loss (avg) = 20.254485, kl = 0.002608
#
# 	Total time elapsed: 69931.396702 sec. Average time per batch: 2.731588 sec
#
# 	iter = 25650, local_loss (cur) = 11.029207, local_loss (avg) = 20.162233, kl = 0.002488
#
# 	Total time elapsed: 70067.322145 sec. Average time per batch: 2.731563 sec
#
# 	iter = 25700, local_loss (cur) = 9.295254, local_loss (avg) = 20.053563, kl = 0.002095
#
# 	Total time elapsed: 70202.420161 sec. Average time per batch: 2.731505 sec
#
# 	iter = 25750, local_loss (cur) = 10.569502, local_loss (avg) = 19.958722, kl = 0.002844
#
# 	Total time elapsed: 70337.901760 sec. Average time per batch: 2.731463 sec
#
# 	iter = 25800, local_loss (cur) = 17.784168, local_loss (avg) = 19.936977, kl = 0.002047
#
# 	Total time elapsed: 70473.810692 sec. Average time per batch: 2.731437 sec
#
# 	iter = 25850, local_loss (cur) = 4.964440, local_loss (avg) = 19.787251, kl = 0.001575
#
# 	Total time elapsed: 70610.132203 sec. Average time per batch: 2.731427 sec
#
# ========== EPOCH 93 ==========
# 	iter = 25900, local_loss (cur) = 11.031143, local_loss (avg) = 19.699690, kl = 0.005346
#
# 	Total time elapsed: 70746.608663 sec. Average time per batch: 2.731424 sec
#
# 	iter = 25950, local_loss (cur) = 32.359158, local_loss (avg) = 19.826285, kl = 0.001921
#
# 	Total time elapsed: 70882.724899 sec. Average time per batch: 2.731406 sec
#
# 	iter = 26000, local_loss (cur) = 24.255537, local_loss (avg) = 19.870577, kl = 0.001443
#
# 	Total time elapsed: 71019.067268 sec. Average time per batch: 2.731398 sec
#
# 	iter = 26050, local_loss (cur) = 21.297249, local_loss (avg) = 19.884844, kl = 0.003877
#
# 	Total time elapsed: 71155.533556 sec. Average time per batch: 2.731394 sec
#
# 	iter = 26100, local_loss (cur) = 17.939125, local_loss (avg) = 19.865387, kl = 0.001911
#
# 	Total time elapsed: 71291.392824 sec. Average time per batch: 2.731366 sec
#
# ========== EPOCH 94 ==========
# 	iter = 26150, local_loss (cur) = 11.494040, local_loss (avg) = 19.781674, kl = 0.003136
#
# 	Total time elapsed: 71427.408881 sec. Average time per batch: 2.731345 sec
#
# 	iter = 26200, local_loss (cur) = 10.588724, local_loss (avg) = 19.689744, kl = 0.003315
#
# 	Total time elapsed: 71563.902661 sec. Average time per batch: 2.731342 sec
#
# 	iter = 26250, local_loss (cur) = 5.720208, local_loss (avg) = 19.550049, kl = 0.095484
#
# 	Total time elapsed: 71700.265703 sec. Average time per batch: 2.731335 sec
#
# 	iter = 26300, local_loss (cur) = 19.214165, local_loss (avg) = 19.546690, kl = 0.002123
#
# 	Total time elapsed: 71835.974847 sec. Average time per batch: 2.731302 sec
#
# 	iter = 26350, local_loss (cur) = 21.196129, local_loss (avg) = 19.563184, kl = 0.003964
#
# 	Total time elapsed: 71971.985759 sec. Average time per batch: 2.731281 sec
#
# 	iter = 26400, local_loss (cur) = 5.968892, local_loss (avg) = 19.427241, kl = 0.003055
#
# 	Total time elapsed: 72107.864954 sec. Average time per batch: 2.731255 sec
#
# ========== EPOCH 95 ==========
# 	iter = 26450, local_loss (cur) = 11.563345, local_loss (avg) = 19.348602, kl = 0.005765
#
# 	Total time elapsed: 72244.113687 sec. Average time per batch: 2.731243 sec
#
# 	iter = 26500, local_loss (cur) = 11.026672, local_loss (avg) = 19.265383, kl = 0.001265
#
# 	Total time elapsed: 72380.545819 sec. Average time per batch: 2.731238 sec
#
# 	iter = 26550, local_loss (cur) = 2.646760, local_loss (avg) = 19.099197, kl = 0.001340
#
# 	Total time elapsed: 72516.617262 sec. Average time per batch: 2.731220 sec
#
# 	iter = 26600, local_loss (cur) = 7.366490, local_loss (avg) = 18.981870, kl = 0.001507
#
# 	Total time elapsed: 72652.627991 sec. Average time per batch: 2.731199 sec
#
# 	iter = 26650, local_loss (cur) = 7.424245, local_loss (avg) = 18.866293, kl = 0.002045
#
# 	Total time elapsed: 72788.105693 sec. Average time per batch: 2.731159 sec
#
# ========== EPOCH 96 ==========
# 	iter = 26700, local_loss (cur) = 13.534077, local_loss (avg) = 18.812971, kl = 0.002797
#
# 	Total time elapsed: 72924.698526 sec. Average time per batch: 2.731160 sec
#
# 	iter = 26750, local_loss (cur) = 24.104149, local_loss (avg) = 18.865883, kl = 0.004542
#
# 	Total time elapsed: 73060.811831 sec. Average time per batch: 2.731143 sec
#
# 	iter = 26800, local_loss (cur) = 13.832294, local_loss (avg) = 18.815547, kl = 0.002621
#
# 	Total time elapsed: 73197.569230 sec. Average time per batch: 2.731151 sec
#
# 	iter = 26850, local_loss (cur) = 0.058980, local_loss (avg) = 18.627982, kl = 0.005468
#
# 	Total time elapsed: 73334.194485 sec. Average time per batch: 2.731153 sec
#
# 	iter = 26900, local_loss (cur) = 16.773153, local_loss (avg) = 18.609433, kl = 0.006057
#
# 	Total time elapsed: 73469.712303 sec. Average time per batch: 2.731115 sec
#
# 	iter = 26950, local_loss (cur) = 15.799235, local_loss (avg) = 18.581331, kl = 0.002069
#
# 	Total time elapsed: 73605.502506 sec. Average time per batch: 2.731086 sec
#
# ========== EPOCH 97 ==========
# 	iter = 27000, local_loss (cur) = 23.043400, local_loss (avg) = 18.625952, kl = 0.002506
#
# 	Total time elapsed: 73742.342966 sec. Average time per batch: 2.731097 sec
#
# 	iter = 27050, local_loss (cur) = 0.950743, local_loss (avg) = 18.449200, kl = 0.007198
#
# 	Total time elapsed: 73878.354970 sec. Average time per batch: 2.731077 sec
#
# 	iter = 27100, local_loss (cur) = 21.430784, local_loss (avg) = 18.479016, kl = 0.001553
#
# 	Total time elapsed: 74014.445341 sec. Average time per batch: 2.731060 sec
#
# 	iter = 27150, local_loss (cur) = 17.017736, local_loss (avg) = 18.464403, kl = 0.001732
#
# 	Total time elapsed: 74150.834264 sec. Average time per batch: 2.731054 sec
#
# 	iter = 27200, local_loss (cur) = 10.874905, local_loss (avg) = 18.388508, kl = 0.004482
#
# 	Total time elapsed: 74287.959227 sec. Average time per batch: 2.731075 sec
#
# ========== EPOCH 98 ==========
# 	iter = 27250, local_loss (cur) = 25.446795, local_loss (avg) = 18.459091, kl = 0.003511
#
# 	Total time elapsed: 74424.218081 sec. Average time per batch: 2.731064 sec
#
# 	iter = 27300, local_loss (cur) = 24.419064, local_loss (avg) = 18.518691, kl = 0.001188
#
# 	Total time elapsed: 74560.632326 sec. Average time per batch: 2.731059 sec
#
# 	iter = 27350, local_loss (cur) = 13.007347, local_loss (avg) = 18.463577, kl = 0.002862
#
# 	Total time elapsed: 74697.554592 sec. Average time per batch: 2.731072 sec
#
# 	iter = 27400, local_loss (cur) = 0.451960, local_loss (avg) = 18.283461, kl = 0.001380
#
# 	Total time elapsed: 74834.624413 sec. Average time per batch: 2.731091 sec
#
# 	iter = 27450, local_loss (cur) = 11.619236, local_loss (avg) = 18.216819, kl = 0.004247
#
# 	Total time elapsed: 74972.666656 sec. Average time per batch: 2.731145 sec
#
# 	iter = 27500, local_loss (cur) = 15.548360, local_loss (avg) = 18.190134, kl = 0.000858
#
# 	Total time elapsed: 75109.205349 sec. Average time per batch: 2.731145 sec
#
# ========== EPOCH 99 ==========
# 	iter = 27550, local_loss (cur) = 2.786458, local_loss (avg) = 18.036097, kl = 0.002567
#
# 	Total time elapsed: 75246.008145 sec. Average time per batch: 2.731153 sec
#
# 	iter = 27600, local_loss (cur) = 19.713497, local_loss (avg) = 18.052871, kl = 0.002130
#
# 	Total time elapsed: 75381.633533 sec. Average time per batch: 2.731120 sec
#
# 	iter = 27650, local_loss (cur) = 9.618431, local_loss (avg) = 17.968527, kl = 0.001897
#
# 	Total time elapsed: 75518.380676 sec. Average time per batch: 2.731127 sec
#
# 	iter = 27700, local_loss (cur) = 29.616262, local_loss (avg) = 18.085004, kl = 0.001115
#
# 	Total time elapsed: 75654.070136 sec. Average time per batch: 2.731095 sec
#
# 	iter = 27750, local_loss (cur) = 10.621399, local_loss (avg) = 18.010368, kl = 0.000982
#
# 	Total time elapsed: 75789.994279 sec. Average time per batch: 2.731073 sec
